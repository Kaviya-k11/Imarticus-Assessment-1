# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=pd.read_csv("C:/Users/admin/Downloads/Paper1/bank.csv",delimiter=';')
df=pd.DataFrame(x)
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df=df.drop_duplicates()
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41176 rows x 21 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr().style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_21844_row0_col0, #T_21844_row1_col1, #T_21844_row2_col2, #T_21844_row3_col3, #T_21844_row4_col4, #T_21844_row5_col5, #T_21844_row6_col6, #T_21844_row7_col7, #T_21844_row8_col8, #T_21844_row9_col9 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_21844_row0_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_21844_row0_col2, #T_21844_row1_col7 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_21844_row0_col3 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_21844_row0_col4, #T_21844_row1_col4 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_21844_row0_col5 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_21844_row0_col6 {
#   background-color: #e8e6f2;
#   color: #000000;
# }
# #T_21844_row0_col7 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_21844_row0_col8, #T_21844_row2_col4 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_21844_row0_col9 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_21844_row1_col0, #T_21844_row5_col0, #T_21844_row6_col0 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_21844_row1_col2, #T_21844_row2_col1, #T_21844_row3_col0, #T_21844_row3_col4, #T_21844_row3_col7, #T_21844_row4_col2, #T_21844_row4_col3, #T_21844_row4_col5, #T_21844_row4_col6, #T_21844_row4_col8, #T_21844_row4_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_21844_row1_col3 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_21844_row1_col5, #T_21844_row2_col6 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_21844_row1_col6 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_21844_row1_col8 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_21844_row1_col9 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_21844_row2_col0, #T_21844_row4_col7, #T_21844_row8_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_21844_row2_col3, #T_21844_row2_col8 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_21844_row2_col5, #T_21844_row7_col9 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_21844_row2_col7, #T_21844_row6_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_21844_row2_col9 {
#   background-color: #aeadd3;
#   color: #000000;
# }
# #T_21844_row3_col1, #T_21844_row9_col0 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_21844_row3_col2 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_21844_row3_col5 {
#   background-color: #a19eca;
#   color: #f1f1f1;
# }
# #T_21844_row3_col6, #T_21844_row6_col4 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_21844_row3_col8 {
#   background-color: #9a96c6;
#   color: #f1f1f1;
# }
# #T_21844_row3_col9 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_21844_row4_col0 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_21844_row4_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_21844_row5_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_21844_row5_col2 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_21844_row5_col3 {
#   background-color: #9490c3;
#   color: #f1f1f1;
# }
# #T_21844_row5_col4 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_21844_row5_col6 {
#   background-color: #5e3b98;
#   color: #f1f1f1;
# }
# #T_21844_row5_col7 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_21844_row5_col8 {
#   background-color: #42057f;
#   color: #f1f1f1;
# }
# #T_21844_row5_col9 {
#   background-color: #491285;
#   color: #f1f1f1;
# }
# #T_21844_row6_col2 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_21844_row6_col3 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_21844_row6_col5 {
#   background-color: #5a3294;
#   color: #f1f1f1;
# }
# #T_21844_row6_col7 {
#   background-color: #edebf4;
#   color: #000000;
# }
# #T_21844_row6_col8 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_21844_row6_col9 {
#   background-color: #7669af;
#   color: #f1f1f1;
# }
# #T_21844_row7_col0 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_21844_row7_col1, #T_21844_row7_col2 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_21844_row7_col3 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_21844_row7_col4, #T_21844_row8_col7 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_21844_row7_col5 {
#   background-color: #aeacd2;
#   color: #000000;
# }
# #T_21844_row7_col6 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_21844_row7_col8 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_21844_row8_col0 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_21844_row8_col2 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_21844_row8_col3 {
#   background-color: #908dc2;
#   color: #f1f1f1;
# }
# #T_21844_row8_col4 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_21844_row8_col5 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_21844_row8_col6 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_21844_row8_col9, #T_21844_row9_col8 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_21844_row9_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_21844_row9_col2 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_21844_row9_col3, #T_21844_row9_col6 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_21844_row9_col4 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_21844_row9_col5 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_21844_row9_col7 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# </style>
# <table id="T_21844_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >duration</th>
#       <th class="col_heading level0 col2" >campaign</th>
#       <th class="col_heading level0 col3" >pdays</th>
#       <th class="col_heading level0 col4" >previous</th>
#       <th class="col_heading level0 col5" >emp.var.rate</th>
#       <th class="col_heading level0 col6" >cons.price.idx</th>
#       <th class="col_heading level0 col7" >cons.conf.idx</th>
#       <th class="col_heading level0 col8" >euribor3m</th>
#       <th class="col_heading level0 col9" >nr.employed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21844_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_21844_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_21844_row0_col1" class="data row0 col1" >-0.000808</td>
#       <td id="T_21844_row0_col2" class="data row0 col2" >0.004622</td>
#       <td id="T_21844_row0_col3" class="data row0 col3" >-0.034381</td>
#       <td id="T_21844_row0_col4" class="data row0 col4" >0.024379</td>
#       <td id="T_21844_row0_col5" class="data row0 col5" >-0.000242</td>
#       <td id="T_21844_row0_col6" class="data row0 col6" >0.001009</td>
#       <td id="T_21844_row0_col7" class="data row0 col7" >0.129075</td>
#       <td id="T_21844_row0_col8" class="data row0 col8" >0.010852</td>
#       <td id="T_21844_row0_col9" class="data row0 col9" >-0.017607</td>
#     </tr>
#     <tr>
#       <th id="T_21844_level0_row1" class="row_heading level0 row1" >duration</th>
#       <td id="T_21844_row1_col0" class="data row1 col0" >-0.000808</td>
#       <td id="T_21844_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_21844_row1_col2" class="data row1 col2" >-0.071765</td>
#       <td id="T_21844_row1_col3" class="data row1 col3" >-0.047556</td>
#       <td id="T_21844_row1_col4" class="data row1 col4" >0.020600</td>
#       <td id="T_21844_row1_col5" class="data row1 col5" >-0.027941</td>
#       <td id="T_21844_row1_col6" class="data row1 col6" >0.005303</td>
#       <td id="T_21844_row1_col7" class="data row1 col7" >-0.008126</td>
#       <td id="T_21844_row1_col8" class="data row1 col8" >-0.032861</td>
#       <td id="T_21844_row1_col9" class="data row1 col9" >-0.044672</td>
#     </tr>
#     <tr>
#       <th id="T_21844_level0_row2" class="row_heading level0 row2" >campaign</th>
#       <td id="T_21844_row2_col0" class="data row2 col0" >0.004622</td>
#       <td id="T_21844_row2_col1" class="data row2 col1" >-0.071765</td>
#       <td id="T_21844_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_21844_row2_col3" class="data row2 col3" >0.052606</td>
#       <td id="T_21844_row2_col4" class="data row2 col4" >-0.079182

# %%
for i in df:
    if df[i].dtypes==object:
        from sklearn.preprocessing import LabelEncoder
        label=LabelEncoder()
        df[i]=label.fit_transform(df[i])
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_13656/2120920183.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=label.fit_transform(df[i])

# %%
x=df.drop(["nr.employed","euribor3m","y","emp.var.rate","cons.price.idx"],axis=1)
y=df.iloc[:,20]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((32940, 16), (8236, 16), (32940,), (8236,))

# %% [markdown]
# ### Using Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier() 
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)
y_pred_train=model.predict(x_train)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9076007770762506

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[7031,  238],
#        [ 523,  444]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7269
#            1       0.65      0.46      0.54       967
#
#     accuracy                           0.91      8236
#    macro avg       0.79      0.71      0.74      8236
# weighted avg       0.90      0.91      0.90      8236

# %% [markdown]
# ### Handling unbalanced data using SMOTE

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\admin\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\admin\anaconda3\lib\site-packages (from imblearn) (0.9.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\admin\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 33)

# %%
oversample = SMOTE()
x, y = oversample.fit_resample(x, y)
x_train_new, y_train_new = sm.fit_resample(x_train, y_train )

# %% [markdown]
# ### Observe that data has been balanced

# %%
pd.Series(y_train_new).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
model.fit(x_train_new, y_train_new)
train_pred_sm = model.predict(x_train_new)
test_pred_sm =model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_pred_sm,y_test)
# Out:
# 0.9065080135988344

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train_new, train_pred_sm)
# Out:
# array([[29268,     0],
#        [    0, 29268]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, test_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      7269
#            1       0.60      0.62      0.61       967
#
#     accuracy                           0.91      8236
#    macro avg       0.77      0.78      0.78      8236
# weighted avg       0.91      0.91      0.91      8236

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
 
x1=df.drop(['y'],axis=1).values
y1=df['y'].values

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20,random_state=0)

# %%
model.fit(xtrain,ytrain)
y_pred=model.predict(xtest)
model.predict_proba(xtest)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[0.09258333, 0.90741667],
#        [0.15164958, 0.84835042],
#        [0.7865927 , 0.2134073 ],
#        ...,
#        [0.16975697, 0.83024303],
#        [0.6144562 , 0.3855438 ],
#        [0.75457566, 0.24542434]])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(ytest,y_pred)
# Out:
# 0.8039001026342798

# %%
confusion_matrix(ytest,y_pred)
# Out:
# array([[6151, 1082],
#        [1784, 5598]], dtype=int64)

# %%
print(classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      7233
#            1       0.84      0.76      0.80      7382
#
#     accuracy                           0.80     14615
#    macro avg       0.81      0.80      0.80     14615
# weighted avg       0.81      0.80      0.80     14615

# %%
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score,auc
from sklearn.metrics import roc_curve

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=0)

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8070607553366174

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      5447
#            1       0.84      0.76      0.80      5515
#
#     accuracy                           0.81     10962
#    macro avg       0.81      0.81      0.81     10962
# weighted avg       0.81      0.81      0.81     10962
